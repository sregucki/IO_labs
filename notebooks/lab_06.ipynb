# %% [markdown]
# # Lab_06 Klasyfikacja zdjęć konwolucyjną siecią neuronową

# %% [markdown]
# ## Zadanie 1

# %%
import numpy as np
from matplotlib import pyplot as plt

# tworzymy tablice o wymiarach 128x128x3 (3 kanaly to RGB)
# uzupelnioną zerami = kolor czarny
data = np.zeros((128, 128, 3), dtype=np.uint8)


# chcemy zeby obrazek byl czarnobialy,
# wiec wszystkie trzy kanaly rgb uzupelniamy tymi samymi liczbami
# napiszmy do tego funkcje
def draw(img, x, y, color):
    img[x, y] = [color, color, color]


# zamalowanie 4 pikseli w lewym górnym rogu
draw(data, 5, 5, 100)
draw(data, 6, 6, 100)
draw(data, 5, 6, 255)
draw(data, 6, 5, 255)


# rysowanie kilku figur na obrazku
for i in range(128):
    for j in range(128):
        if (i - 64) ** 2 + (j - 64) ** 2 < 900:
            draw(data, i, j, 200)
        elif i > 100 and j > 100:
            draw(data, i, j, 255)
        elif (i - 15) ** 2 + (j - 110) ** 2 < 25:
            draw(data, i, j, 150)
        elif (i - 15) ** 2 + (j - 110) ** 2 == 25 or (i - 15) ** 2 + (
            j - 110
        ) ** 2 == 26:
            draw(data, i, j, 255)

# konwersja macierzy na obrazek i wyświetlenie
plt.imshow(data, interpolation="nearest")
plt.show()

# %%
import numpy as np
from scipy.signal import convolve2d
from scipy import ndimage

# strade = 1
kernel = np.array([[1, 0, -1], [1, 0, -1], [1, 0, -1]])
edges = np.zeros((128, 128, 3), dtype=np.uint8)
for channel in range(3):
    current_channel = data[:, :, channel]
    edges_channel = convolve2d(current_channel, kernel, mode="same")
    edges_channel = np.clip(edges_channel, 0, 255).astype(np.uint8)
    edges[:, :, channel] = edges_channel

plt.imshow(edges, interpolation="nearest")
plt.title("kernel = [[1, 0, -1],[1, 0, -1],[1, 0, -1]], strade = 1")
# Out:
# Text(0.5, 1.0, 'kernel = [[1, 0, -1],[1, 0, -1],[1, 0, -1]], strade = 1')

# %%
kernel = np.array([[1, 0, -1], [1, 0, -1], [1, 0, -1]])
edges = np.zeros((128, 128, 3), dtype=np.uint8)
for channel in range(3):
    current_channel = data[:, :, channel]
    edges_channel = convolve2d(current_channel, kernel, mode="same")
    edges_channel = np.clip(edges_channel, 0, 255).astype(np.uint8)
    edges_channel = edges_channel[::2, ::2]
    edges[: edges_channel.shape[0], : edges_channel.shape[1], channel] = edges_channel

plt.imshow(edges, interpolation="nearest")
plt.title("kernel = [[1, 0, -1],[1, 0, -1],[1, 0, -1]], strade = 2")
# Out:
# Text(0.5, 1.0, 'kernel = [[1, 0, -1],[1, 0, -1],[1, 0, -1]], strade = 2')

# %%
kernel = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])
edges = np.zeros((128, 128, 3), dtype=np.uint8)
for channel in range(3):
    current_channel = data[:, :, channel]
    edges_channel = convolve2d(current_channel, kernel, mode="same")
    edges_channel = np.clip(edges_channel, 0, 255).astype(np.uint8)
    edges[:, :, channel] = edges_channel

plt.imshow(edges, interpolation="nearest")
plt.title("kernel = [[1, 1, 1],[0, 0, 0],[-1,-1,-1]], strade = 1")
# Out:
# Text(0.5, 1.0, 'kernel = [[1, 1, 1],[0, 0, 0],[-1,-1,-1]], strade = 1')

# %%
kernel = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])
edges = np.zeros((128, 128, 3), dtype=np.uint8)
for channel in range(3):
    current_channel = data[:, :, channel]
    edges_channel = convolve2d(current_channel, kernel, mode="same")
    edges_channel = np.clip(edges_channel, 0, 255).astype(np.uint8)
    edges_channel = edges_channel[::2, ::2]
    edges[: edges_channel.shape[0], : edges_channel.shape[1], channel] = edges_channel

plt.imshow(edges, interpolation="nearest")
plt.title("kernel = [[1, 1, 1],[0, 0, 0],[-1,-1,-1]], strade = 2")
# Out:
# Text(0.5, 1.0, 'kernel = [[1, 1, 1],[0, 0, 0],[-1,-1,-1]], strade = 2')

# %%
kernel = np.array([[0, 1, 2], [-1, 0, 1], [-2, -1, 0]])
edges = np.zeros((128, 128, 3), dtype=np.uint8)
for channel in range(3):
    current_channel = data[:, :, channel]
    edges_channel = convolve2d(current_channel, kernel, mode="same")
    edges_channel = np.clip(edges_channel, 0, 255).astype(np.uint8)
    edges[:, :, channel] = edges_channel

plt.imshow(edges, interpolation="nearest")
plt.title("kernel = sobel 45 degrees, strade = 1")
# Out:
# Text(0.5, 1.0, 'kernel = sobel 45 degrees, strade = 1')

# %%
kernel = np.array([[0, 1, 2], [-1, 0, 1], [-2, -1, 0]])
edges = np.zeros((128, 128, 3), dtype=np.uint8)
for channel in range(3):
    current_channel = data[:, :, channel]
    edges_channel = convolve2d(current_channel, kernel, mode="same")
    edges_channel = np.clip(edges_channel, 0, 255).astype(np.uint8)
    edges_channel = edges_channel[::2, ::2]
    edges[: edges_channel.shape[0], : edges_channel.shape[1], channel] = edges_channel

plt.imshow(edges, interpolation="nearest")
plt.title("kernel = sobel 45 degrees, strade = 1")
# Out:
# Text(0.5, 1.0, 'kernel = sobel 45 degrees, strade = 1')

# %% [markdown]
# ## Zadanie 2

# %%
import os
import pandas as pd
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

filenames = os.listdir("data/dogs-cats-mini/")

categories = []
for filename in filenames:
    category = filename.split(".")[0]
    if category == "dog":
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({"filename": filenames, "category": categories})
sns.countplot(data=df, x="category", palette="tab10")
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
from keras.models import Sequential
from keras.layers import (
    Conv2D,
    MaxPooling2D,
    Dropout,
    Flatten,
    Dense,
    Activation,
    BatchNormalization,
)

model = Sequential()

model.add(
    Conv2D(
        32,
        (3, 3),
        activation="relu",
        input_shape=(128, 128, 3),
    )
)
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation="softmax"))

# %%
model.compile(
    loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 126, 126, 32)      896
#
#  batch_normalization_4 (Bat  (None, 126, 126, 32)      128
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 63, 63, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_5 (Bat  (None, 61, 61, 64)        256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_6 (Bat  (None, 28, 28, 128)       512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 14, 14, 128)       0
#
# ...

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(
    monitor="val_acc", patience=2, verbose=1, factor=0.5, min_lr=0.00001
)
callbacks = [earlystop, learning_rate_reduction]

# %%
from cgi import test
from sklearn.model_selection import train_test_split

df["category"] = df["category"].replace({0: "cat", 1: "dog"})

train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
test_df = validate_df[:400]
validate_df = validate_df[400:]
validate_df = validate_df.reset_index(drop=True)
train_df = train_df.reset_index(drop=True)

total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size = 15

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1.0 / 255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "data/dogs-cats-mini",
    x_col="filename",
    y_col="category",
    target_size=(128, 128),
    class_mode="categorical",
    batch_size=batch_size,
)

validation_datagen = ImageDataGenerator(rescale=1.0 / 255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    "data/dogs-cats-mini/",
    x_col="filename",
    y_col="category",
    target_size=(128, 128),
    class_mode="categorical",
    batch_size=batch_size,
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.
# Found 4600 validated image filenames belonging to 2 classes.

# %%
FAST_RUN = False

epochs = 3 if FAST_RUN else 50
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate // batch_size,
    steps_per_epoch=total_train // batch_size,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# ...
# 1333/1333 [==============================] - 126s 94ms/step - loss: 0.7655 - accuracy: 0.6167 - val_loss: 0.8673 - val_accuracy: 0.5547 - lr: 0.0010
# Epoch 2/50
# ...
# 1333/1333 [==============================] - 127s 96ms/step - loss: 0.6116 - accuracy: 0.6793 - val_loss: 0.6192 - val_accuracy: 0.6573 - lr: 0.0010
# Epoch 3/50
# ...
# 1333/1333 [==============================] - 131s 98ms/step - loss: 0.5838 - accuracy: 0.7047 - val_loss: 0.5564 - val_accuracy: 0.7218 - lr: 0.0010
# Epoch 4/50
# ...
# 1333/1333 [==============================] - 132s 99ms/step - loss: 0.5577 - accuracy: 0.7230 - val_loss: 0.5496 - val_accuracy: 0.7425 - lr: 0.0010
# Epoch 5/50
# ...
# 1333/1333 [==============================] - 127s 95ms/step - loss: 0.5355 - accuracy: 0.7387 - val_loss: 0.8909 - val_accuracy: 0.5915 - lr: 0.0010
# Epoch 6/50
# ...
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.5145 - accuracy: 0.7524 - val_loss: 0.4741 - val_accuracy: 0.7815 - lr: 0.0010
# Epoch 7/50
# ...

# %%
from matplotlib import pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
ax1.plot(history.history["loss"], color="b", label="Training loss")
ax1.plot(history.history["val_loss"], color="r", label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history["accuracy"], color="b", label="Training accuracy")
ax2.plot(history.history["val_accuracy"], color="r", label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc="best", shadow=True)
plt.tight_layout()
plt.show()

# %%
test_gen = ImageDataGenerator(rescale=1.0 / 255)
test_generator = test_gen.flow_from_dataframe(
    test_df,
    "data/dogs-cats-mini/",
    x_col="filename",
    y_col=None,
    class_mode=None,
    target_size=(128, 128),
    batch_size=batch_size,
    shuffle=False,
)
# Out:
# Found 400 validated image filenames.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

test_df["category"] = test_df["category"].replace({"dog": 1, "cat": 0})
predict = model.predict_generator(
    test_generator, steps=np.ceil(test_df.shape[0] / batch_size)
)

cm = confusion_matrix(test_df["category"], np.argmax(predict, axis=1))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["cat", "dog"])

disp.plot()

print(
    f"Accuracy: {accuracy_score(test_df['category'], np.argmax(predict, axis=1)) * 100}%"
)
# Out:
# Accuracy: 61.5%

# %%
model.compile(loss="MSLE", optimizer="SGD", metrics=["accuracy"])

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate // batch_size,
    steps_per_epoch=total_train // batch_size,
    callbacks=callbacks,
)

test_df["category"] = test_df["category"].replace({"dog": 1, "cat": 0})
predict = model.predict_generator(
    test_generator, steps=np.ceil(test_df.shape[0] / batch_size)
)

cm = confusion_matrix(test_df["category"], np.argmax(predict, axis=1))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["cat", "dog"])

disp.plot()

print(
    f"Accuracy: {accuracy_score(test_df['category'], np.argmax(predict, axis=1)) * 100}%"
)
# Out:
# Epoch 1/50
# ...
# 1333/1333 [==============================] - 105s 79ms/step - loss: 0.0550 - accuracy: 0.8415 - val_loss: 0.1028 - val_accuracy: 0.6229 - lr: 0.0100
# Epoch 2/50
# ...
# 1333/1333 [==============================] - 107s 80ms/step - loss: 0.0540 - accuracy: 0.8451 - val_loss: 0.1409 - val_accuracy: 0.5203 - lr: 0.0100
# Epoch 3/50
# ...
# 1333/1333 [==============================] - 106s 79ms/step - loss: 0.0599 - accuracy: 0.8281 - val_loss: 0.1060 - val_accuracy: 0.6627 - lr: 0.0100
# Epoch 4/50
# ...
# 1333/1333 [==============================] - 105s 79ms/step - loss: 0.0597 - accuracy: 0.8276 - val_loss: 0.0616 - val_accuracy: 0.8340 - lr: 0.0100
# Epoch 5/50
# ...
# 1333/1333 [==============================] - 106s 79ms/step - loss: 0.0552 - accuracy: 0.8406 - val_loss: 0.0618 - val_accuracy: 0.8577 - lr: 0.0100
# Epoch 6/50
# ...
# 1333/1333 [==============================] - 107s 80ms/step - loss: 0.0549 - accuracy: 0.8431 - val_loss: 0.0643 - val_accuracy: 0.8514 - lr: 0.0100
# Epoch 7/50
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))
ax1.plot(history.history["loss"], color="b", label="Training loss")
ax1.plot(history.history["val_loss"], color="r", label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history["accuracy"], color="b", label="Training accuracy")
ax2.plot(history.history["val_accuracy"], color="r", label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc="best", shadow=True)
plt.tight_layout()
plt.show()

# %%
model = Sequential()

model.add(
    Conv2D(
        32,
        (3, 3),
        activation="relu",
        input_shape=(128, 128, 3),
    )
)
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation="softmax"))

# %%
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate // batch_size,
    steps_per_epoch=total_train // batch_size,
    callbacks=callbacks,
)

test_df["category"] = test_df["category"].replace({"dog": 1, "cat": 0})
predict = model.predict_generator(
    test_generator, steps=np.ceil(test_df.shape[0] / batch_size)
)

cm = confusion_matrix(test_df["category"], np.argmax(predict, axis=1))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["cat", "dog"])

disp.plot()

print(
    f"Accuracy: {accuracy_score(test_df['category'], np.argmax(predict, axis=1)) * 100}%"
)
# Out:
# Epoch 1/50
# ...
# 1333/1333 [==============================] - 76s 57ms/step - loss: 0.7896 - accuracy: 0.5646 - val_loss: 2.0793 - val_accuracy: 0.5499 - lr: 0.0100
# Epoch 2/50
# ...
# 1333/1333 [==============================] - 80s 60ms/step - loss: 0.7217 - accuracy: 0.5955 - val_loss: 0.8036 - val_accuracy: 0.5638 - lr: 0.0100
# Epoch 3/50
# ...
# 1333/1333 [==============================] - 82s 62ms/step - loss: 0.6895 - accuracy: 0.6218 - val_loss: 1.0195 - val_accuracy: 0.5900 - lr: 0.0100
# Epoch 4/50
# ...
# 1333/1333 [==============================] - 82s 62ms/step - loss: 0.6775 - accuracy: 0.6347 - val_loss: 0.7225 - val_accuracy: 0.6366 - lr: 0.0100
# Epoch 5/50
# ...
# 1333/1333 [==============================] - 81s 61ms/step - loss: 0.6654 - accuracy: 0.6444 - val_loss: 0.6404 - val_accuracy: 0.6778 - lr: 0.0100
# Epoch 6/50
# ...
# 1333/1333 [==============================] - 80s 60ms/step - loss: 0.6462 - accuracy: 0.6607 - val_loss: 0.6435 - val_accuracy: 0.6821 - lr: 0.0100
# Epoch 7/50
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))
ax1.plot(history.history["loss"], color="b", label="Training loss")
ax1.plot(history.history["val_loss"], color="r", label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history["accuracy"], color="b", label="Training accuracy")
ax2.plot(history.history["val_accuracy"], color="r", label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc="best", shadow=True)
plt.tight_layout()
plt.show()
